# %% [markdown]
# # **第４回 ネットワーク構造の統計モデル**

# %% [markdown]
# ## **問題１：相関係数を用いたネットワークの類似性の計算**
# `data/A1_edges.csv`と`data/A2_edges.csv`のエッジリストを読み込み、ネットワークを定義して可視化、２つのネットワークの隣接行列に対する相関係数を計算するプログラムを`ns2a_04_01.py`として作成した。相関係数の値はいくつか小数点第２位までで答えよ。

# %%
# ns2a_04_01.py を実行する
# %run ns2a_04_01.py

# %% [markdown]
# ## **問題２：QAP検定によるネットワークの類似性の評価**
# 問題１で求めたネットワーク間の類似性は統計的に高い値であるか。ノード配置をランダム化して生成されるネットワークに対して、全通り相関係数を求め、ヒストグラムを作成するプログラムを`ns2a_04_02.py`として作成した。問題１で求めた相関係数（小数点第２位を切り捨てた値）は、上位何％に含まれるか。

# %%
# ns2a_04_02.py を実行する
# %run ns2a_04_02.py

# %% [markdown]
# ## **問題３:確率的ブロックモデルによるグラフ生成**
# 確率的ブロックモデルを用いてグラフを生成するプログラムを`ns2a_04_03.py`として作成した。以下のようにモデルのパラメータを変更した場合、どのようなネットワークが生成されるか答えよ。ただし、ノード数を100とし、前半と後半で属性が異なるものとする。
# - p_in > p_out
# - p_in < p_out

# %%
# ns2a_04_03.py を実行する
# %run ns2a_04_03.py
