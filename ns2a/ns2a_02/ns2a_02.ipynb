# %% [markdown]
# # **第２回 次数相関、同類性**

# %% [markdown]
# ## **問題１**
# `Zachary’s Karate Club`のネットワークを定義して可視化、ノードリストを`data/karate_club_nodes.csv`として出力するプログラムを`ns2a_02_01.py`として作成した。このネットワークの属性毎のノード数はいくつか確認せよ。

# %%
# ns2a_02_01.py を実行する
# %run ns2a_02_01.py

# %% [markdown]
# ## **問題２**
# `Zachary’s Karate Club`のネットワークを定義して次数と属性の同時分布行列を出力するプログラムを`ns2a_02_02.py`として作成した。このネットワークにおいて、同じ属性同士が結合するエッジ数及び異なる属性同士が結合するエッジ数はいくつか確認せよ。

# %%
# ns2a_02_02.py を実行する
# %run ns2a_02_02.py

# %% [markdown]
# ## **問題３**
# `Zachary’s Karate Club`のネットワークを定義して次数相関係数と属性の同類選択性係数を計算するプログラムを`ns2a_02_03.py`として作成した。次数相関係数と属性の同類選択性係数の値はいくつか小数点以下第３位までの数値で答えよ。また、それぞれ親和的か排他的か選択せよ。

# %%
# ns2a_02_03.py を実行する
# %run ns2a_02_03.py
