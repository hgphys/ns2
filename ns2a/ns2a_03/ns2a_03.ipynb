# %% [markdown]
# # **第３回 ノード間の類似性、リンク予測**

# %% [markdown]
# ## **問題１**
# `Zachary’s Karate Club`のネットワークを定義して可視化、選択した２つのノードの隣接ノードと、共通して隣接するノードの数を出力するプログラムを`ns2a_03_01.py`として作成した。ノード９と１９は隣接しているか。また、これら２つノードで共通して隣接するノードの数はいくつか答えよ。

# %%
# ns2a_03_01.py を実行する
# %run ns2a_03_01.py

# %% [markdown]
# ## **問題２**
# `Zachary’s Karate Club`のネットワークを定義して選択した２つのノードの代表的なノード間の類似度を計算するプログラムを`ns2a_03_02.py`として作成した。ノード０と３３に対して、以下の代表的なノード間の類似度を計算せよ。
# - Common neighbors（CN）
# - Jaccard coefficient（JC）
# - Adamic/Adar（AA）
# - Preferential attachment（PA）

# %%
# ns2a_03_02.py を実行する
# %run ns2a_03_02.py

# %% [markdown]
# ## **問題３**
# `Zachary’s Karate Club`のネットワークを定義してネットワークを定義してエッジが存在しないノード間の類似度を計算して、その類似度が高い順に出力するリンク予測プログラムを`ns2a_03_03.py`として作成した。以下の代表的なノード間の類似度において、リンクされた結果を答えよ。
# - Common neighbors（CN）
# - Jaccard coefficient（JC）
# - Adamic/Adar（AA）
# - Preferential attachment（PA）

# %%
# ns2a_03_03.py を実行する
# %run ns2a_03_03.py
