# %% [markdown]
# # **第２回 ネットワークの可視化（描画）**

# %% [markdown]
# ## **問題：ばね電気モデルによるネットワークの可視化**
# `NetworkX`を用いて`Zachary’s Karate Club`のネットワークを定義して可視化するプログラムを実装して、以下の問いに答えよ。
# ただし、空手クラブのネットワークは、`G = nx.karate_club_graph()`として読み込み、属性について`Mr. Hi`を青、`Officer` を赤として可視化すること。
# - IDが3であるノードの色
# - 円形配置 `nx.circular_layout(G)`　のとき、IDが0であるノードの座標（小数点以下第１位までの数値）
# - 力学モデル `nx.spring_layout(G)`と`nx.kamada_kawai_layout(G)`でより属性を分離できているのはどちらか

# %%
import networkx as nx
import matplotlib.pyplot as plt

# 空手クラブのネットワークを読み込み
G = nx.karate_club_graph()

# 各クラブの色を指定


# ノードの色をクラブに応じて設定


# ノード配置と描画
