# %% [markdown]
# # **ns2b_05-07 実践演習課題**
#
# - 学籍番号:
# - 氏名:
#
# >はじめに、自身の学籍番号のネットワークデータをダウンロードして、``data``に保存してください。購入履歴のデータを用いて、２部グラフを作成、プロジェクションを行うことで、商品と購入者の性質を分析を行いましょう。以下に指定のネットワーク特徴量の分析に関するレポートを作成してください。コードだけでなく、テキストセルを作成して、分析結果を文章化する必要があります。整数値でないネットワークの特徴量は、小数点第2位までの数値で答えてください。Google フォームへの回答だけでなく、このファイルをMoodleコースから提出する必要があります。
